# %% [markdown]
# ![Lyrics Genius Logo](LyricsGenius.png)
#
# Lyrics Scraper to collect dataset by artists.

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# %%
artist_name = "Estopa"

# %%
def get_lyrics_from_artist_df(artist, num_songs = None):
    url = 'https://www.lyrics.com/artist/' + artist.split(' ')[0].lower()
    for i in range(1,len(artist.split())):
        url += '%20' + artist.split(' ')[i].lower()
        
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    
    son = []

    songs = soup.find_all('td', {'class': 'tal qx'})

    base_url = 'https://www.lyrics.com/'
    print("Number of Songs found for "+str(artist)+": "+str(len(songs)))
    lyr = []
    iterspace = len(songs)
    
    if num_songs:
        iterspace = min(num_songs, iterspace)
        
    for i in range(iterspace):
        print("\nProcessing: "+str(songs[i].text))
        if songs[i].a is None:
            pass
        else:
            lyr_url = base_url + songs[i].a.attrs['href']
            r = requests.get(lyr_url)
            son.append(songs[i].text)
            soup = BeautifulSoup(r.text, 'html.parser')
            lyr.append(soup.find('pre', {'id': 'lyric-body-text'}).text)
          

    df = pd.DataFrame({'song': son,  'lyrics': lyr})
    return df

# %%
def lyrics_cleaning(x):
    fixed = ''
    lyr_lst = x.split('\r\n')
    
    for item in lyr_lst[:-1]:
        fixed += item + ' '
        
    fixed += lyr_lst[-1]
    return fixed

# %%
df = get_lyrics_from_artist_df(artist_name)
# Out:
# Number of Songs found for Estopa: 164
#
# Processing: Atrapado
#
# Processing: Fuego
#
# Processing: Corazón Sin Salida
#
# Processing: Despertar
#
# Processing: Pobre Siri
#
# Processing: Yo No Estoy Loco
#
# Processing: Escrita En La Frente
#
# Processing: Nadie Sabe
#
# Processing: Pastillas para Dormir
#
# Processing: Estatua de Sal
#
# Processing: Ando Buscando
#
# Processing: Gafas de Rosa
#
# Processing: Con el Viento
#
# Processing: Se Me Olvida la Vida
#
# Processing: Donde Va Mi Alma
#
# Processing: Mundo Marrón
#
# Processing: Corona de Espinas
#
# Processing: Tonto
#
# Processing: Sin Sombrero
#
# Processing: Como Camarón
#
# Processing: Tu Calorro
#
# Processing: Ya No Me Acuerdo
#
# Processing: El Run Run
#
# Processing: Hemicraneal
#
# Processing: Partiendo la Pana
#
# Processing: Vino Tinto
#
# Processing: Me Falta el Aliento
#
# Processing: Run Run
#
# Processing: Fuente De Energía
#
# Processing: No Quiero Verla Más
#
# Processing: Tu Calorro
#
# Processing: Ya No Me Acuerdo
#
# Processing: Cacho a Cacho
#
# Processing: Era
#
# Processing: Cuerpo Triste
#
# Processing: Demonios
#
# Processing: Como Camarón
#
# Processing: Luna Lunera
#
# Processing: El Del Medio De Los Chichos
#
# Processing: Tan Solo
#
# Processing: Cuando Amanece
#
# Processing: Cuando Cae La Luna
#
# Processing: Me Falta El Aliento
#
# Processing: Vino Tinto
#
# Processing: La Raja De Tu Falda
#
# Processing: Exiliado En El Lavabo
#
# Processing: Malabares
#
# Processing: Pastillas De Freno
#
# Processing: Descatalogando
#
# Processing: No Quiero Verla Mas
#
# Processing: Cuando Amanece
#
# Processing: Cuerpo Triste
#
# Processing: Era
#
# Processing: La Matraka
#
# Processing: Descatalogando
#
# Processing: Hemicraneal
#
# Processing: Jugar al Despiste
#
# Processing: El Run Run
#
# Processing: Vientos de Tormenta
#
# Processing: Pesadilla
#
# Processing: Vino Tinto
#
# Processing: La Raja de Tu Falda
#
# Processing: Malabares
#
# Processing: Con la Mano Levantá
#
# Processing: Tu Calorro
#
# Processing: Malabares
#
# Processing: Lunes
#
# Processing: No Quiero Verla Más
#
# Processing: Ni Pa Ti Ni Pa Mí
#
# Processing: Malabares
#
# Processing: Lunes
#
# Processing: No Quíero Verla Más
#
# Processing: Ní Pa Tí Ní Pa Mí
#
# Processing: Fuente de Energia
#
# Processing: Partiendo la Pana
#
# Processing: Jardin del Olvido
#
# Processing: Fin de Semana
#
# Processing: Apagón
#
# Processing: Fuente de Energía
#
# Processing: Penas Con Rumba
#
# Processing: Corazón Aerodinámico
#
# Processing: Ya No Me Acuerdo
#
# Processing: Estrella Fugaz
#
# Processing: Tanta Tinta Tonta
#
# Processing: Tragicomedia
#
# Processing: Necesito Medicación
#
# Processing: Pastillas de Freno
#
# Processing: Cuando Cae la Luna
#
# Processing: Luna Lunera
#
# Processing: Suma y Sigue
#
# Processing: La Raja de Tu Falda
#
# Processing: Vino Tinto
#
# Processing: Luna Lunera
#
# Processing: Destrangis in the Night
#
# Processing: Demonios
#
# Processing: Jardín del Olvido
#
# Processing: El Blade
#
# Processing: Te VI Te VI
#
# Processing: Nasío Pa la Alegría
#
# Processing: Vuelvo a las Andadas
#
# Processing: Ké Pasa!?
#
# Processing: Partiendo la Pana
#
# Processing: Mi Primera Cana
#
# Processing: Ojitos Rojos [En Directo]
#
# Processing: Vino Tinto
#
# Processing: Luna Lunera
#
# Processing: Destrangis in the Night
#
# Processing: Demonios
#
# Processing: Jardín del Olvido
#
# Processing: El Blade
#
# Processing: Te VI Te VI
#
# Processing: Nasío Pa la Alegría
#
# Processing: Vuelvo a las Andadas
#
# Processing: Ké Pasa!?
#
# Processing: Partiendo la Pana
#
# Processing: Mi Primera Cana
#
# Processing: Ojitos Rojos [En Directo][*]
#
# Processing: Me Falta el Aliento
#
# Processing: Tu Calorro
#
# Processing: Tragicomedia
#
# Processing: Cuando Amanece
#
# Processing: Pastillas para Dormir
#
# Processing: No Quiero Verla Más
#
# Processing: Vino Tinto
#
# Processing: Exiliado en el Lavabo
#
# Processing: Fuente de Energia
#
# Processing: Me Falta el Aliento
#
# Processing: Luna Lunera
#
# Processing: Demonios
#
# Processing: Cuerpo Triste
#
# Processing: Cuando Cae la Luna
#
# Processing: Pastillas de Freno
#
# Processing: Partiendo la Pana
#
# Processing: Hemicraneal
#
# Processing: Estatua de Sal
#
# Processing: Cacho a Cacho
#
# Processing: Malabares
#
# Processing: El Run Run
#
# Processing: Ya No Me Acuerdo
#
# Processing: Como Camarón
#
# Processing: Nasío pa la Alegría
#
# Processing: Era
#
# Processing: El Del Medio de los Chichos
#
# Processing: Fin de Semana
#
# Processing: Tu Calorro
#
# Processing: La Raja de Tu Faloa
#
# Processing: Me Falta el Aliento
#
# Processing: Tan Sólo
#
# Processing: Poquito a Poco
#
# Processing: Suma y Sigue
#
# Processing: El del Medio de los Chichos
#
# Processing: Como Camarón
#
# Processing: Exiliado en el Lavabo
#
# Processing: Estopa
#
# Processing: Cacho a Cacho
#
# Processing: Bossanova
#
# Processing: El Diario No Hablaba de Tí
#
# Processing: Ya No Me Acuerdo
#
# Processing: Cacho a cacho
#
# Processing: La Serpiente Y La Luna
#
# Processing: Camiseta De Rokanrol
#
# Processing: Los Globos
#
# Processing: El Último Renglón
#
# Processing: La Rueda De La Fortuna

# %%
df = df.drop_duplicates()

# %%
df['lyrics'] = df['lyrics'].apply(lyrics_cleaning)
lyrics = list(df['lyrics'])

# %%
with open("data/estopa-lyrics.txt","w",encoding="utf-8") as file:
    for item in lyrics:
        file.write('%s\n' % item)
